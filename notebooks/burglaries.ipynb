# %% [markdown]
# Analyzing Aggravated Burglaries in Davidson County

# %%
import requests
import matplotlib.pyplot as plt
from IPython.display import Image
import pandas as pd
import json

# %% [markdown]
# 1. A dataset containing details about Metro Nashville Police Department reported incidents is available at 'https://data.nashville.gov/Police/Metro-Nashville-Police-Department-Incidents/2u6v-ujjs'. Make use of the API to find all aggravated burglary incidents that were reported during the six month period from January 1, 2021 through June 30, 2021.

# %% [markdown]
# #Read API key using json library

# %% [markdown]
# with open('data/nasa.json') as fi:
#     credentials = json.load(fi)
#
# api_key = credentials['api_key']

# %% [markdown]
# #Make and API call

# %%
url = 'https://data.nashville.gov/resource/2u6v-ujjs.json'
response = requests.get(url)

# %%
#response[:1000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-70e6dbef6dcf> in <module>
# ----> 1 response[:1000]
#
# TypeError: 'Response' object is not subscriptable

# %%
#df = pd.read_csv('https://data.nashville.gov/resource/2u6v-ujjs.csv').sort_values('incident_reported', ascending=False)
#df
# Out:
#         primary_key  incident_number report_type report_type_description  \
# 2    20210513823_11      20210513823           D              DISPATCHED
# 1    20210513835_11      20210513835           D              DISPATCHED
# 3    20210513703_11      20210513703           D              DISPATCHED
# 4    20210513650_11      20210513650           D              DISPATCHED
# 6    20210513609_12      20210513609           D              DISPATCHED
# ..              ...              ...         ...                     ...
# 997  20210505300_11      20210505300           D              DISPATCHED
# 996  20210505302_11      20210505302           D              DISPATCHED
# 998  20210505297_11      20210505297           S                 SUSPECT
# 995  20210505310_11      20210505310           D              DISPATCHED
# 0     2021260418_11       2021260418           W                 WITNESS
#
#     incident_status_code incident_status_description investigation_status  \
# ...

# %%
df['incident_reported']= df['incident_reported'].str.split('T', expand=True)[0]

#reported_incidents=reported_incidents.loc[:,['incident_reported']>2021].head()

# %%
df['incident_reported'][0]
# Out:
# '2021-04-21'

# %%
df[(df['incident_reported']<='2021-09-01') & (df['incident_reported']>='2021-02-01')]
# Out:
#      primary_key  incident_number report_type report_type_description  \
# 0  2021260418_11       2021260418           W                 WITNESS
#
#   incident_status_code incident_status_description investigation_status  \
# 0                    O                        OPEN                 Open
#
#          incident_occurred incident_reported incident_location  ...  \
# 0  2021-04-14T17:00:00.000        2021-04-21      HILLSIDE AVE  ...
#
#    weapon_description  victim_number  domestic_related  victim_type  \
# 0                NONE              1             False            I
#
#          victim_description  victim_gender victim_race  victim_ethnicity  \
# 0  INDIVIDUAL (18 AND OVER)              M           W      Non-Hispanic
#
#   victim_county_resident       mapped_location
# 0               RESIDENT  POINT (-86.78 36.14)
#
# [1 rows x 31 columns]

# %%
df['incident_reported'] = pd.to_datetime(df['incident_reported'])

# %%
df[(df['incident_reported']<='2021-09-01') & (df['incident_reported']>='2021-02-01')]
# Out:
#      primary_key  incident_number report_type report_type_description  \
# 0  2021260418_11       2021260418           W                 WITNESS
#
#   incident_status_code incident_status_description investigation_status  \
# 0                    O                        OPEN                 Open
#
#          incident_occurred incident_reported incident_location  ...  \
# 0  2021-04-14T17:00:00.000        2021-04-21      HILLSIDE AVE  ...
#
#    weapon_description  victim_number  domestic_related  victim_type  \
# 0                NONE              1             False            I
#
#          victim_description  victim_gender victim_race  victim_ethnicity  \
# 0  INDIVIDUAL (18 AND OVER)              M           W      Non-Hispanic
#
#   victim_county_resident       mapped_location
# 0               RESIDENT  POINT (-86.78 36.14)
#
# [1 rows x 31 columns]
